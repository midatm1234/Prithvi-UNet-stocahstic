# %% [markdown]
# # Prithvi WxC Downscaling with CORDEX Data: Model Fine-tuning

# %% [markdown]
# This notebook demonstrates how to fine-tune the `Prithvi` downscaling model on CORDEX NZ data.
#
# We show how to set up the model, load the pretrained weights, and run finetuning using the CORDEX-derived inputs.

# %% [markdown]
# The datasets are from https://zenodo.org/records/17517423

# %% [markdown]
# ---
#
# ## Setup
#
# Python >= 3.10 is required

# %% [markdown]
# Make sure that your current working directory is `granite-wxc/`

# %%
import os
from pathlib import Path
REPO_ROOT = Path("/mnt/data2/kyo/granite-wxc").resolve()
os.chdir("/mnt/data2/kyo/granite-wxc/examples/CORDEX_ML")
print(f"Working directory set to: {Path.cwd()}")
# Out:
# Working directory set to: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML

# %%
# Select idle GPUs before any CUDA initialization
import os
import subprocess

MIN_FREE_GB = 20  # adjust if needed
MAX_GPUS = None  # set to an int to cap GPU count

def _select_idle_gpus(min_free_gb=8, max_gpus=None):
    if os.environ.get('CUDA_VISIBLE_DEVICES'):
        visible = os.environ['CUDA_VISIBLE_DEVICES'].split(',')
        return [int(v) for v in visible if v.strip() != '']
    try:
        out = subprocess.check_output(
            [
                'nvidia-smi',
                '--query-gpu=index,memory.free',
                '--format=csv,noheader,nounits',
            ],
            text=True,
        )
    except Exception as exc:
        print(f'GPU auto-selection skipped (nvidia-smi unavailable): {exc}')
        return None
    rows = []
    for line in out.strip().splitlines():
        if not line.strip():
            continue
        idx_str, free_str = line.split(',')
        idx = int(idx_str.strip())
        free_mb = int(free_str.strip())
        rows.append((idx, free_mb))
    rows.sort(key=lambda x: x[1], reverse=True)
    selected = [idx for idx, free_mb in rows if free_mb >= min_free_gb * 1024]
    if max_gpus is not None:
        selected = selected[:max_gpus]
    return selected

selected_gpus = _select_idle_gpus(MIN_FREE_GB, MAX_GPUS)
if selected_gpus:
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
    os.environ['CUDA_VISIBLE_DEVICES'] = ','.join(str(i) for i in selected_gpus)
    NUM_GPUS = len(selected_gpus)
    print(f"Using idle GPUs (CUDA_VISIBLE_DEVICES={os.environ['CUDA_VISIBLE_DEVICES']})")
else:
    NUM_GPUS = None
    print('Using default CUDA_VISIBLE_DEVICES (no idle GPU filter applied).')
# Out:
# Using idle GPUs (CUDA_VISIBLE_DEVICES=1,2,3)

# %%
# ===================== USER PARAMETERS (EDIT ME) =====================
from nz_params import UserParams, validate_paths


PROJECT_DIR = REPO_ROOT / "examples/CORDEX_ML"
DATASET_ROOT = REPO_ROOT / "granite-geospatial-wxc-downscaling/CORDEX/NZ_domain"

TRAIN_SPLIT = "train/Emulator_hist_future"
PREDICTOR_FILE = "ACCESS-CM2_1961-1980_2080-2099_regridded.nc"
TARGET_FILE = "pr_tasmax_ACCESS-CM2_1961-1980_2080-2099.nc"

TRAIN_PREDICTORS = [DATASET_ROOT / TRAIN_SPLIT / "predictors" / PREDICTOR_FILE]
TRAIN_TARGETS = [DATASET_ROOT / TRAIN_SPLIT / "target" / TARGET_FILE]

RUN_NAME_OVERRIDE = 'NZ_T2_ACCESS-CM2_static'  # e.g., 'nz_debug_run'
USE_STATIC = True  # set False to ignore static/orography inputs

P = UserParams(
    repo_root=REPO_ROOT,
    project_dir=PROJECT_DIR,
    runs_root=PROJECT_DIR / "runs/NZ_T2_ACCESS-CM2_static_train",
    config_path=PROJECT_DIR / "NZ_T2_ACCESS-CM2_static.yaml",
    run_name=RUN_NAME_OVERRIDE,
    train_predictor_paths=TRAIN_PREDICTORS,
    train_target_paths=TRAIN_TARGETS,
    val_predictor_paths=TRAIN_PREDICTORS,
    val_target_paths=TRAIN_TARGETS,
    test_predictor_paths=TRAIN_PREDICTORS,
    test_target_paths=TRAIN_TARGETS,
    use_static=USE_STATIC,
    device_target="cuda",
    batch_size=1,
    num_workers=2,
    preferred_checkpoint="best",
)

validate_paths(P)
print(P.summary())
# Out:
# Repo root: /mnt/data2/kyo/granite-wxc
# Project dir: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML
# Runs root: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train
# Config: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/NZ_T2_ACCESS-CM2_static.yaml
# Run name override: NZ_T2_ACCESS-CM2_static
# Inference run override: <latest>
# Preferred checkpoint: best
# Use static inputs: True
# Device target: cuda
# Batch size override: 1
# Dataloader workers override: 2
# Train predictors: 1 file(s)
# Validation predictors: 1 file(s)
# Test predictors: 1 file(s)
# Checkpoint path override: <auto>

# %% [markdown]
# If your current directory is not `granite-wxc/`, change it using the following command:
#
# ```bash
# %cd <local>/granite-wxc/
# ```
#
# Replace `<local>` with the appropriate path prefix

# %%
# !pip install -q git+https://github.com/NASA-IMPACT/Prithvi-WxC.git

# %%
import os
import logging
import warnings

logging.disable(logging.CRITICAL)
warnings.simplefilter(action='ignore', category=FutureWarning)

os.chdir(P.project_dir)
print(f"Project directory set to: {os.getcwd()}")
# Out:
# Project directory set to: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.distributed import DistributedSampler

from cordex_dataset import CordexDownscaleDataset
from cordex_training import (
    get_dataloaders as build_cordex_dataloaders,
    create_finetune_model,
    run_training as launch_cordex_training,
)
from granitewxc.utils.config import get_config
from granitewxc.utils.distributed import init_ddp
from granitewxc.models.model import get_finetune_model_UNET, get_finetune_model
from granitewxc.utils.plot import plot_loss
# Out:
# Pysteps configuration file found at: /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages/pysteps/pystepsrc

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset

from cordex_dataset import CordexDownscaleDataset
from granitewxc.utils.config import get_config
from granitewxc.utils.distributed import init_ddp
from granitewxc.models.model import get_finetune_model_UNET, get_finetune_model
from granitewxc.utils.plot import plot_loss

# %% [markdown]
# Run setup utilities from `examples/CORDEX_ML/run_utils.py` are imported below and rely on the repository path specified in the parameter cell.

# %%
torch.jit.enable_onednn_fusion(True)
if torch.cuda.is_available():
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True
torch.manual_seed(123)

# %% [markdown]
# It is possible to use a cpu or gpu/s to generate inferences. Based on avaiablity of a `cuda:gpu`, we set the device that the model uses

# %%
target = (getattr(P, 'device_target', 'auto') or 'auto').lower()
if target == 'cuda':
    if not torch.cuda.is_available():
        raise RuntimeError("device_target is 'cuda' but no CUDA device is available.")
    device = torch.device('cuda')
    use_gpu = True
elif target == 'cpu':
    device = torch.device('cpu')
    use_gpu = False
else:
    if torch.cuda.is_available():
        device = torch.device('cuda')
        use_gpu = True
    else:
        device = torch.device('cpu')
        use_gpu = False

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# We initialize the Distributed Data Parallel (DDP) environment to leverage multiple GPUs for training

# %%
from pathlib import Path

config_path = P.config_path
config = get_config(str(config_path))
config.device_target = getattr(P, 'device_target', config.device_target)
if getattr(P, "use_static", None) is not None:
    config.data.use_static = bool(P.use_static)

def _override(attr: str, values):
    if values:
        setattr(config.data, attr, [str(Path(p).resolve()) for p in values])

_override('training_predictor_paths', P.train_predictor_paths)
_override('training_target_paths', P.train_target_paths)
_override('validation_predictor_paths', P.val_predictor_paths)
_override('validation_target_paths', P.val_target_paths)
_override('test_predictor_paths', P.test_predictor_paths)
_override('test_target_paths', P.test_target_paths)

if P.batch_size is not None:
    config.batch_size = int(P.batch_size)
if P.num_workers is not None:
    config.dl_num_workers = int(P.num_workers)

train_dl, val_dl = build_cordex_dataloaders(config, use_gpu)
len(train_dl), len(val_dl)
# Out:
# (14600, 14600)

# %% [markdown]
# ## Configuration File
#
# The model is configured using `YAML` files.
#
# In these files, you specify:
# - Paths to the input data
# - Locations of the pretrained weights
#
# To ensure compatibility with the provided weights during inference, keep the model configuration consistent with the original definitions

# %%
import os

os.chdir(P.repo_root)
# !pip install -e .
os.chdir(P.project_dir)
# Out:
# Obtaining file:///mnt/data2/kyo/granite-wxc
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: prithviwxc>=0.1.0 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (1.0.0)
# Requirement already satisfied: xarray>=2024.9.0 in /home/kyo/.local/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (2025.6.1)
# Requirement already satisfied: scipy in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (1.15.3)
# Requirement already satisfied: wget>=1.21.4 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (3.2)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/kyo/.local/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (6.0.3)
# Requirement already satisfied: h5netcdf>=1.3.0 in /home/kyo/.local/lib/python3.10/site-packages (from granitewxc==0.1.1rc1) (1.7.3)
# Requirement already satisfied: h5py in /home/kyo/.local/lib/python3.10/site-packages (from h5netcdf>=1.3.0->granitewxc==0.1.1rc1) (3.15.1)
# Requirement already satisfied: packaging in /home/kyo/.local/lib/python3.10/site-packages (from h5netcdf>=1.3.0->granitewxc==0.1.1rc1) (25.0)
# Requirement already satisfied: numpy~=1.26 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.26.4)
# Requirement already satisfied: pandas in /home/kyo/.local/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.3.3)
# Requirement already satisfied: torch>=2.2 in /home/kyo/.local/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.66.4 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (4.67.1)
# Requirement already satisfied: requests in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.32.5)
# Requirement already satisfied: requests-cache in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.2.1)
# Requirement already satisfied: huggingface_hub>=0.25 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.2.2)
# Requirement already satisfied: filelock in /home/kyo/.local/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/kyo/.local/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (0.28.1)
# Requirement already satisfied: shellingham in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.5.4)
# Requirement already satisfied: typer-slim in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (4.15.0)
# Requirement already satisfied: anyio in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (4.11.0)
# Requirement already satisfied: certifi in /home/kyo/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.0.9)
# Requirement already satisfied: idna in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.11)
# Requirement already satisfied: h11>=0.16 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (0.16.0)
# Requirement already satisfied: networkx in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.3)
# Requirement already satisfied: jinja2 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/kyo/.local/lib/python3.10/site-packages (from torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/kyo/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kyo/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kyo/.local/lib/python3.10/site-packages (from pandas->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/kyo/.local/lib/python3.10/site-packages (from pandas->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/kyo/.local/lib/python3.10/site-packages (from pandas->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/kyo/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kyo/.local/lib/python3.10/site-packages (from jinja2->torch>=2.2->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from requests->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from requests->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.5.0)
# Requirement already satisfied: attrs>=21.2 in /home/kyo/.local/lib/python3.10/site-packages (from requests-cache->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from requests-cache->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/kyo/.local/lib/python3.10/site-packages (from requests-cache->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (4.5.1)
# Requirement already satisfied: url-normalize>=1.4 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from requests-cache->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (2.2.1)
# Requirement already satisfied: click>=8.0.0 in /mnt/data2/kyo/mamba/envs/Prithvi/lib/python3.10/site-packages (from typer-slim->huggingface_hub>=0.25->prithviwxc>=0.1.0->granitewxc==0.1.1rc1) (8.3.0)
# Building wheels for collected packages: granitewxc
#   Building editable for granitewxc (pyproject.toml) ... done
#   Created wheel for granitewxc: filename=granitewxc-0.1.1rc1-0.editable-py3-none-any.whl size=7229 sha256=c19af74b40718b1c11afead15927ac5449ec7fc332f075f6199753f1c0caee96
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tq3m45l8/wheels/2e/5a/11/41fce76ea3198050a52e231f82b3b2c64b4f69dcb246e0a2b6
# Successfully built granitewxc
# Installing collected packages: granitewxc
#   Attempting uninstall: granitewxc
#     Found existing installation: granitewxc 0.1.1rc1
#     Uninstalling granitewxc-0.1.1rc1:
#       Successfully uninstalled granitewxc-0.1.1rc1
# Successfully installed granitewxc-0.1.1rc1

# %%
# Configuration already loaded using the USER PARAMETERS block.

# %%
# Working directory managed via the parameter cell.

# %%
from datetime import datetime
from pathlib import Path

from run_utils import (
    copy_scalars_to_run,
    prepare_run_paths,
    snapshot_resolved_config,
    update_manifest,
    write_manifest,
)
from nz_params import resolve_run_dir, export_params

RUN_NAME, resolved_run_dir = resolve_run_dir(P, config)
run_paths = prepare_run_paths(Path(P.runs_root), RUN_NAME)
assert run_paths.run_dir == resolved_run_dir

config.path_experiment = str(run_paths.run_dir)
config.checkpoint_dir = str(run_paths.checkpoints)
config.scalar_dir = str(run_paths.scalars)
config.preproc_dir = str(run_paths.preproc)

scalar_records = copy_scalars_to_run(config, run_paths.scalars)
resolved_config_path = snapshot_resolved_config(
    config, run_paths.config_dir / "resolved.yaml"
)
manifest = write_manifest(
    run_paths,
    run_name=RUN_NAME,
    base_config=str(config_path),
    resolved_config=resolved_config_path,
    scalars=scalar_records,
)

params_json = export_params(P, run_paths.run_dir / "params.json", extra={"run_name": RUN_NAME})
print(f"Run artifacts will be stored in {run_paths.run_dir}")
print(f"Config snapshot: {resolved_config_path}")
print(f"Saved parameter snapshot to {params_json}")
# Out:
# Run artifacts will be stored in /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static
# Config snapshot: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/config/resolved.yaml
# Saved parameter snapshot to /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/params.json

# %% [markdown]
# ## Dataloader
#
# In this CORDEX example we will use a single regridded data pair for both training and validation.

# %%
# This cell is deprecated; please use the helper functions defined earlier for dataloaders.

# %% [markdown]
# ### Sample shapes
#
# We check the batched tensor shapes from the CORDEX dataloader.

# %%
example_batch = next(iter(train_dl))
if "static_x" in example_batch:
    example_batch["x"].shape, example_batch["y"].shape, example_batch["static_x"].shape
else:
    example_batch["x"].shape, example_batch["y"].shape

# %%
target_shape = tuple(example_batch["y"].shape)
var_names = list(config.data.output_vars)
print(f"Configured output variables: {var_names}")
print(f"Sample target tensor shape: {target_shape}")
if target_shape[1] != len(var_names):
    raise ValueError(
        f"Dataloader returned {target_shape[1]} channels but config specifies {len(var_names)}"
    )
missing_expected = {"pr", "tasmax"} - set(var_names)
if missing_expected:
    raise ValueError(f"Missing expected NZ targets: {sorted(missing_expected)}")
print("Fine-tuning includes both 'pr' and 'tasmax'.")
# Out:
# Configured output variables: ['pr', 'tasmax']
# Sample target tensor shape: (1, 2, 128, 128)
# Fine-tuning includes both 'pr' and 'tasmax'.

# %% [markdown]
# ## Model Initialization
#
# We provide **2** different model architectures `UNET-like` and `CONV`
#
# Both architectures include:
# 1. **Patch Embedding**: Extracts shallow features from the input data
# 2. **Feature Extraction**: Utilizes the Prithvi backbone to extract deeper features
#
# The key difference is that the UNET-like version incorporates **static high-resolution data** into the model

# %% [markdown]
# In this notebook, we use the **UNET-like** version
#
# To switch to the **CONV** model, update the configuration file accordingly and use `get_finetune_model(config)`

# %%
model = create_finetune_model(config).to(device)
# Out:
# Creating the model.
# --> model has 254,372,744 params.
# Loaded 200 tensors from /mnt/data2/kyo/granite-wxc/granite-geospatial-wxc-downscaling/ECCC/weights/best_rmse_UNET_small.pt. Skipped 8 mismatched entries.

# %% [markdown]
# We can now load the pretrained weights

# %%
# Pretrained weights are loaded via create_finetune_model().

# %% [markdown]
# ## Finetuning
#
# The model is now ready for training

# %%
from torch.optim import AdamW
from torch.cuda.amp import GradScaler
from torch.optim.lr_scheduler import CosineAnnealingLR

from granitewxc.utils.trainer import train_model
from granitewxc.models.loss import rmse_loss

# %% [markdown]
# ##
# Defining the optimizer, scaler, and scheduler for the training process.

# %%
# Optimizer configuration handled inside cordex_training.run_training.

# %% [markdown]
# We'll train the model using just 1 data pair and run it for only 5 epochs
#
# Let's train it for a couple of epochs based on the configuration file

# %%
try:
    train_losses, val_losses = launch_cordex_training(config, num_gpus=(NUM_GPUS or torch.cuda.device_count()), save_every=5)
except Exception as exc:
    print(f"Training failed: {exc}")
    raise
# Out:
# Creating the model.
# --> model has 254,372,744 params.
# /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/cordex_training.py:305: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=use_gpu and torch.cuda.is_available())
# [rank2]:[W126 03:56:51.561747185 ProcessGroupNCCL.cpp:4115] [PG ID 0 PG GUID 0 Rank 2]  using GPU 2 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device,or call init_process_group() with a device_id.
# Loaded 200 tensors from /mnt/data2/kyo/granite-wxc/granite-geospatial-wxc-downscaling/ECCC/weights/best_rmse_UNET_small.pt. Skipped 8 mismatched entries.
# /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/cordex_training.py:305: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=use_gpu and torch.cuda.is_available())
# [rank1]:[W126 03:56:52.253473737 ProcessGroupNCCL.cpp:4115] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device,or call init_process_group() with a device_id.
# /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/cordex_training.py:305: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=use_gpu and torch.cuda.is_available())
# [rank0]:[W126 03:56:52.322890640 ProcessGroupNCCL.cpp:4115] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect.Specify device_ids in barrier() to force use of a particular device,or call init_process_group() with a device_id.
# Learning rate: 5e-05Learning rate: 5e-05
#
# Rank 2 starting epoch 1...
# Rank 1 starting epoch 1...
# Learning rate: 5e-05
# Rank 0 starting epoch 1...
# Training Epoch 1/5:   0%|          | 0/200 [00:00<?, ?batch/s]/home/kyo/.local/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/kyo/.local/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/kyo/.local/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Training Epoch 1/5: 100%|██████████| 200/200 [07:36<00:00,  2.28s/batch, loss=4.67, lr=4.54e-5]
# Validation Epoch: 100%|██████████| 50/50 [00:37<00:00,  1.33batch/s, loss=10.1]
# [rank1]:[E126 04:15:06.926336859 ProcessGroupNCCL.cpp:616] [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600001 milliseconds before timing out.
# [rank1]:[E126 04:15:06.926496628 ProcessGroupNCCL.cpp:1785] [PG ID 0 PG GUID 0(default_pg) Rank 1] Exception (either an error or timeout) detected by watchdog at work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank1]:[E126 04:15:06.926506978 ProcessGroupNCCL.cpp:1834] [PG ID 0 PG GUID 0(default_pg) Rank 1] Timeout at NCCL work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank1]:[E126 04:15:06.926515919 ProcessGroupNCCL.cpp:630] [Rank 1] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank1]:[E126 04:15:06.926527949 ProcessGroupNCCL.cpp:636] [Rank 1] To avoid data inconsistency, we are taking the entire process down.
# [rank1]:[E126 04:15:06.927758134 ProcessGroupNCCL.cpp:1595] [PG ID 0 PG GUID 0(default_pg) Rank 1] Process group watchdog thread terminated with exception: [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600001 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f52cbaa0446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f52ccde7a92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f52ccdeeed3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f52ccdf093d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f5315dd85c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7f5318646609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7f5318411353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# terminate called after throwing an instance of 'c10::DistBackendError'
#   what():  [PG ID 0 PG GUID 0(default_pg) Rank 1] Process group watchdog thread terminated with exception: [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600001 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f52cbaa0446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f52ccde7a92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f52ccdeeed3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f52ccdf093d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f5315dd85c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7f5318646609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7f5318411353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# Exception raised from ncclCommWatchdog at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:1601 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f52cbaa0446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe7eb1b (0x7f52cca65b1b in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x145c0 (0x7f5315dd85c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x8609 (0x7f5318646609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #4: clone + 0x43 (0x7f5318411353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# [rank0]:[E126 04:15:06.967598195 ProcessGroupNCCL.cpp:616] [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=_ALLGATHER_BASE, NumelIn=7143425, NumelOut=21430275, Timeout(ms)=600000) ran for 600041 milliseconds before timing out.
# [rank0]:[E126 04:15:06.967710851 ProcessGroupNCCL.cpp:1785] [PG ID 0 PG GUID 0(default_pg) Rank 0] Exception (either an error or timeout) detected by watchdog at work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank0]:[E126 04:15:06.967721141 ProcessGroupNCCL.cpp:1834] [PG ID 0 PG GUID 0(default_pg) Rank 0] Timeout at NCCL work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank0]:[E126 04:15:06.967726002 ProcessGroupNCCL.cpp:630] [Rank 0] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank0]:[E126 04:15:06.967729722 ProcessGroupNCCL.cpp:636] [Rank 0] To avoid data inconsistency, we are taking the entire process down.
# [rank0]:[E126 04:15:06.968902353 ProcessGroupNCCL.cpp:1595] [PG ID 0 PG GUID 0(default_pg) Rank 0] Process group watchdog thread terminated with exception: [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=_ALLGATHER_BASE, NumelIn=7143425, NumelOut=21430275, Timeout(ms)=600000) ran for 600041 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fcfde456446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7fcfdf79da92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7fcfdf7a4ed3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7fcfdf7a693d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7fd02878e5c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7fd02affc609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7fd02adc7353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# terminate called after throwing an instance of 'c10::DistBackendError'
#   what():  [PG ID 0 PG GUID 0(default_pg) Rank 0] Process group watchdog thread terminated with exception: [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=_ALLGATHER_BASE, NumelIn=7143425, NumelOut=21430275, Timeout(ms)=600000) ran for 600041 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fcfde456446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7fcfdf79da92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7fcfdf7a4ed3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7fcfdf7a693d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7fd02878e5c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7fd02affc609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7fd02adc7353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# Exception raised from ncclCommWatchdog at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:1601 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fcfde456446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe7eb1b (0x7fcfdf41bb1b in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x145c0 (0x7fd02878e5c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x8609 (0x7fd02affc609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #4: clone + 0x43 (0x7fd02adc7353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# [rank2]:[E126 04:15:06.019524160 ProcessGroupNCCL.cpp:616] [Rank 2] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600094 milliseconds before timing out.
# [rank2]:[E126 04:15:06.019636406 ProcessGroupNCCL.cpp:1785] [PG ID 0 PG GUID 0(default_pg) Rank 2] Exception (either an error or timeout) detected by watchdog at work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank2]:[E126 04:15:06.019643556 ProcessGroupNCCL.cpp:1834] [PG ID 0 PG GUID 0(default_pg) Rank 2] Timeout at NCCL work: 17006, last enqueued NCCL work: 17006, last completed NCCL work: 17005.
# [rank2]:[E126 04:15:06.019648656 ProcessGroupNCCL.cpp:630] [Rank 2] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank2]:[E126 04:15:06.019655527 ProcessGroupNCCL.cpp:636] [Rank 2] To avoid data inconsistency, we are taking the entire process down.
# [rank2]:[E126 04:15:06.020830068 ProcessGroupNCCL.cpp:1595] [PG ID 0 PG GUID 0(default_pg) Rank 2] Process group watchdog thread terminated with exception: [Rank 2] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600094 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f00c82bf446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f00c9606a92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f00c960ded3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f00c960f93d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f01125f75c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7f0114e65609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7f0114c30353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# terminate called after throwing an instance of 'c10::DistBackendError'
#   what():  [PG ID 0 PG GUID 0(default_pg) Rank 2] Process group watchdog thread terminated with exception: [Rank 2] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=17006, OpType=ALLREDUCE, NumelIn=1, NumelOut=1, Timeout(ms)=600000) ran for 600094 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f00c82bf446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f00c9606a92 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f00c960ded3 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f00c960f93d in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f01125f75c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x8609 (0x7f0114e65609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #6: clone + 0x43 (0x7f0114c30353 in /lib/x86_64-linux-gnu/libc.so.6)
#
# Exception raised from ncclCommWatchdog at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:1601 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f00c82bf446 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe7eb1b (0x7f00c9284b1b in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x145c0 (0x7f01125f75c0 in /home/kyo/.local/lib/python3.10/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x8609 (0x7f0114e65609 in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #4: clone + 0x43 (0x7f0114c30353 in /lib/x86_64-linux-gnu/libc.so.6)
# Distributed training failed with signal/exit (process 1 terminated with signal SIGABRT); retrying on a single GPU.
# Creating the model.
# --> model has 254,372,744 params.
# Loaded 200 tensors from /mnt/data2/kyo/granite-wxc/granite-geospatial-wxc-downscaling/ECCC/weights/best_rmse_UNET_small.pt. Skipped 8 mismatched entries.
# Learning rate: 5e-05
# Rank 0 starting epoch 1...
# WARNING: Not calling set_epoch.
# Training Epoch 1/5:   0%|          | 0/200 [00:00<?, ?batch/s]/home/kyo/.local/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Training Epoch 1/5: 100%|██████████| 200/200 [05:40<00:00,  1.70s/batch, loss=2.71, lr=4.54e-5]
# WARNING: Not calling set_epoch.
# Validation Epoch: 100%|██████████| 50/50 [00:28<00:00,  1.72batch/s, loss=7.55]
# --> saved /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt
# Learning rate: 4.5320916362186205e-05
# Rank 0 starting epoch 2...
# WARNING: Not calling set_epoch.
# Training Epoch 2/5: 100%|██████████| 200/200 [05:26<00:00,  1.63s/batch, loss=3.85, lr=3.31e-5]
# WARNING: Not calling set_epoch.
# Validation Epoch: 100%|██████████| 50/50 [00:29<00:00,  1.72batch/s, loss=5.67]
# --> saved /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt
# Learning rate: 3.30709163621862e-05
# Rank 0 starting epoch 3...
# WARNING: Not calling set_epoch.
# Training Epoch 3/5: 100%|██████████| 200/200 [05:26<00:00,  1.63s/batch, loss=3.47, lr=1.8e-5]
# WARNING: Not calling set_epoch.
# Validation Epoch: 100%|██████████| 50/50 [00:29<00:00,  1.72batch/s, loss=4.43]
# --> saved /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt
# Learning rate: 1.7929083637813794e-05
# Rank 0 starting epoch 4...
# WARNING: Not calling set_epoch.
# Training Epoch 4/5: 100%|██████████| 200/200 [05:26<00:00,  1.63s/batch, loss=4.08, lr=5.72e-6]
# WARNING: Not calling set_epoch.
# Validation Epoch: 100%|██████████| 50/50 [00:29<00:00,  1.72batch/s, loss=4.48]
# --> saved /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt
# Learning rate: 5.679083637813779e-06
# Rank 0 starting epoch 5...
# WARNING: Not calling set_epoch.
# Training Epoch 5/5: 100%|██████████| 200/200 [05:26<00:00,  1.63s/batch, loss=2.49, lr=1e-6]
# WARNING: Not calling set_epoch.
# Validation Epoch: 100%|██████████| 50/50 [00:29<00:00,  1.72batch/s, loss=4.16]
# --> saved /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt

# %%
from pathlib import Path

checkpoint_info = {
    "best": str(Path(config.checkpoint_dir) / "best.ckpt"),
    "last": str(Path(config.checkpoint_dir) / "last.ckpt"),
}
manifest = update_manifest(run_paths.run_dir, checkpoints=checkpoint_info)
print("Updated run manifest with checkpoint locations:")
for label, ckpt_path in checkpoint_info.items():
    print(f"  {label}: {ckpt_path}")
# Out:
# Updated run manifest with checkpoint locations:
#   best: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/best.ckpt
#   last: /mnt/data2/kyo/granite-wxc/examples/CORDEX_ML/runs/NZ_T2_ACCESS-CM2_static_train/NZ_T2_ACCESS-CM2_static/checkpoints/last.ckpt

# %%
plot_loss(train_losses, val_losses)
